# %% [markdown]
# ## <img src="./fiuba.jpg" align="right" width="150" />
# #### Procesamiento Digital de Señales
#
# # Trabajo Práctico 2
# #### Nombre y Apellido Rodrigo Tirapegui
#
# ***
# ## Filtrado

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Para el siguiente filtro digital se pide:
#
# </div>

# %% [markdown]
#  $$ y(k) = \frac{1}{N} \sum_{i=0}^{N-1} x(k-i)  $$
#
#  Para N = [3; 5]

# %% [markdown]
#    a) El diagrama de polos y ceros y su respuesta de módulo y fase

# %% [markdown]
# <img src="./escriba_aqui.png" align="center" width="50%" />

# %% [markdown]
#    b) Corrobore su respuesta mediante la simulación computacional

# %%
#%% Inicialización
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import patches
from matplotlib.figure import Figure
from matplotlib import rcParams
import scipy.signal as sig

#%% Generación de señales de prueba

def zplane(b,a,filename=None):
    """
    Plot the complex z-plane given a transfer function.
    """

    # get a figure/plot
    ax = plt.subplot(111)

    # create the unit circle
    uc = patches.Circle((0,0), radius=1, fill=False,
                        color='black', ls='dashed')
    ax.add_patch(uc)

    # The coefficients are less than 1, normalize the coeficients
    if np.max(b) > 1:
        kn = np.max(b)
        b = b/float(kn)
    else:
        kn = 1

    if np.max(a) > 1:
        kd = np.max(a)
        a = a/float(kd)
    else:
        kd = 1
        
    # Get the poles and zeros
    p = np.roots(a)
    z = np.roots(b)
    k = kn/float(kd)
    
    # Plot the zeros and set marker properties    
    t1 = plt.plot(z.real, z.imag, 'go', ms=10)
    plt.setp( t1, markersize=10.0, markeredgewidth=1.0,
              markeredgecolor='k', markerfacecolor='g')

    # Plot the poles and set marker properties
    t2 = plt.plot(p.real, p.imag, 'rx', ms=10)
    plt.setp( t2, markersize=12.0, markeredgewidth=3.0,
              markeredgecolor='r', markerfacecolor='r')

    ax.spines['left'].set_position('center')
    ax.spines['bottom'].set_position('center')
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    # set the ticks
    r = 1.5; plt.axis('scaled'); plt.axis([-r, r, -r, r])
    ticks = [-1, -.5, .5, 1]; plt.xticks(ticks); plt.yticks(ticks)

    if filename is None:
        plt.show()
    else:
        plt.savefig(filename)
    

    return z, p, k

def plot_module_and_phase(ww, hh):

    # Creo una figura y un subgráfico
    fig, ax1 = plt.subplots()

    # Escribo título del gráfico
    ax1.set_title('Respuesta en frecuencia filtro FIR')

    # Grafico respuesta de módulo
    ax1.plot(ww, 20 * np.log10(abs(hh)), color='b')

    # Escribo título eje y
    ax1.set_ylabel('Amplitud [dB]', color='b')

    # Escribo título eje x
    ax1.set_xlabel('Frecuencia normalizada')

    # Genero segundo subgráfico
    ax2 = ax1.twinx()

    # Grafico respuesta de fase
    ax2.plot(ww, np.unwrap(np.angle(hh)), color='g')

    # Agrego título eje y
    ax2.set_ylabel('Angulo [rad]', color='g')

    # Dibujo la grilla
    ax2.grid()

    # Muestro la figura
    plt.show()

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# Función transferencia: N = 3
k = (1/3)
b = np.array([1, 1, 1])
a = np.array([1, 0, 0])

# Calculo la respuesta en frecuencia
[ww, hh] = sig.freqz(k*b, a)

# Normalizo el vector de frecuencias
ww = ww / np.pi

# Gráfico de respuesta de módulo y fase #
plot_module_and_phase(ww, hh)

# Grafico diagrama de polos y ceros #
zplane(k*b, a)
# Out:
# (array([-0.5+0.8660254j, -0.5-0.8660254j]), array([0., 0.]), 1.0)

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# Función transferencia: N = 5
k = (1/5)
b = np.array([1, 1, 1, 1, 1])
a = np.array([1, 0, 0, 0, 0])

# Calculo la respuesta en frecuencia
[ww, hh] = sig.freqz(k*b, a)

# Normalizo el vector de frecuencias
ww = ww / np.pi

# Gráfico de respuesta de módulo y fase #

# Gráfico de respuesta de módulo y fase #
plot_module_and_phase(ww, hh)

# Grafico diagrama de polos y ceros #
zplane(k*b, a)
# Out:
# (array([ 0.30901699+0.95105652j,  0.30901699-0.95105652j,
#         -0.80901699+0.58778525j, -0.80901699-0.58778525j]),
#  array([0., 0., 0., 0.]),
#  1.0)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2)</b> Para el siguiente filtro digital se pide:
#
# </div>

# %% [markdown]
# $$ h(k) = (-1, 1) $$

# %% [markdown]
#    a) El diagrama de polos y ceros y su respuesta de módulo y fase

# %% [markdown]
# <img src="./escriba_aqui.png" align="center" width="50%" />

# %% [markdown]
#    b) Corrobore su respuesta mediante simulación computacional

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# EJERCICIO 2

k = 1
b = np.array([-1, 1])
a = np.array([1, 0])

# Calculo la respuesta en frecuencia
[ww, hh] = sig.freqz(k*b, a)

# Normalizo el vector de frecuencias
ww = ww / np.pi

#%% Presentación gráfica de los resultados

# Gráfico de respuesta de módulo y fase #
plot_module_and_phase(ww, hh)

# Grafico diagrama de polos y ceros #
zplane(k*b, a)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:79: RuntimeWarning: divide by zero encountered in log10
# (array([1.]), array([0.]), 1.0)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3)</b> Para el siguiente filtro digital se pide:
#
# </div>

# %% [markdown]
# <img src="./comb.png" align="center" width="30%" />
#
#
# Para $N= (2; 4)$ y $b = -1$

# %% [markdown]
#    a) El diagrama de polos y ceros y su respuesta de módulo y fase

# %% [markdown]
# <img src="./escriba_aqui.png" align="center" width="50%" />

# %% [markdown]
#    b) Corrobore su respuesta mediante simulación computacional

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################
# EJERCICIO 3

# Función transferencia: N = 2

k = 1
b = np.array([1, 0, -1])
a = np.array([1, 0, 0])

# Calculo la respuesta en frecuencia
[ww, hh] = sig.freqz(k*b, a)

# Normalizo el vector de frecuencias
ww = ww / np.pi

#%% Presentación gráfica de los resultados

# Gráfico de respuesta de módulo y fase #
plot_module_and_phase(ww, hh)

# Grafico diagrama de polos y ceros #
zplane(k*b, a)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:79: RuntimeWarning: divide by zero encountered in log10
# (array([ 1., -1.]), array([0., 0.]), 1.0)

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################
# EJERCICIO 3

# Función transferencia: N = 4

k = 1
b = np.array([1, 0, 0, 0, -1])
a = np.array([1, 0, 0, 0, 0])

# Calculo la respuesta en frecuencia
[ww, hh] = sig.freqz(k*b, a)

# Normalizo el vector de frecuencias
ww = ww / np.pi

#%% Presentación gráfica de los resultados

# Gráfico de respuesta de módulo y fase #
plot_module_and_phase(ww, hh)

# Grafico diagrama de polos y ceros #
zplane(k*b, a)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:79: RuntimeWarning: divide by zero encountered in log10
# (array([-1.00000000e+00+0.j,  8.32667268e-17+1.j,  8.32667268e-17-1.j,
#          1.00000000e+00+0.j]), array([0., 0., 0., 0.]), 1.0)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>4)</b> En el archivo <i>ECG_TP4.mat</i> encontrará un registro electrocardiográfico (ECG) registrado durante una prueba de esfuerzo, junto con una serie de variables descriptas a continuación. Diseñe y aplique los filtros digitales necesarios para mitigar las siguientes fuentes de contaminación:
# </div>

# %% [markdown]
#  - Ruido causado por el movimiento de los electrodos (Alta frecuencia)
#  - Ruido muscular (Alta frecuencia)
#  - Movimiento de la línea de base del ECG, inducido en parte por la respiración (Baja frecuencia)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Los latidos presentes en el registro de ECG, alineados y clasificados (de origen normal y ventricular) poseen las siguientes características temporales y frecuenciales:
# </div>

# %% [markdown]
# <img src="./latidos_tiempo.png" align="center" width="80%" />
#
# <img src="./latido_promedio.png" align="center" width="80%" />
#
# <img src="./latidos_espectro.png" align="center" width="80%" />

# %% [markdown]
# ### Archivo *ECG_TP4.mat*
# (variables)
#  - **ecg_lead**: Registro de ECG muestreado a $fs=1$ KHz durante una prueba de esfuerzo
#  - **qrs_pattern1**: Complejo de ondas QRS normal
#  - **heartbeat_pattern1**: Latido normal
#  - **heartbeat_pattern2**: Latido de origen ventricular
#  - **qrs_detections**: vector con las localizaciones (en # de muestras) donde ocurren los latidos
#
# a) Establezca una plantilla de diseño para los filtros digitales que necesitará para que la señal de ECG se asemeje a los latidos promedio en cuanto a *suavidad* de los trazos y nivel isoeléctrico nulo.

# %%
# Defina la plantilla del filtro

fs0 = 50 Hz # fin de la banda de detenida 0
fc0 = 1 Hz # comienzo de la banda de paso
fc1 = 45 Hz # fin de la banda de paso
fs1 = 0.5 Hz # comienzo de la banda de detenida 1
# Out:
#   File "<ipython-input-16-c51c1d7bcc28>", line 3
#     fs0 = 45 Hz # fin de la banda de detenida 0
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# b) ¿Cómo obtuvo dichos valores?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Estudiando las señales ECG, se busca que los filtros utilizados reduzcan la interferencia de red en la señal promediada y que se eliminen los transitorios antes y despues del complejo QRS, pues un transitorio podría confundirse con los potenciales ventriculares tardíos.
#     Para filtrar este tipo de ruido se utilizan filtros paso-alto con frecuencia de corte entre 0.5 y 1 Hz para eliminar actividades de muy baja frecuencia tales como las señales electrogalvánicas de los electrodos o artefactos de movimiento. También se debe aplicar un filtro paso-bajo con frecuencia de corte entre 35 y 70 Hz para evitar artefactos de elevada frecuencia como la actividad muscular.
#        Tomando como piso de ruido 50mV, se decide generar un filtro pasa-bajo que atenúe por debajo del piso de ruido las señales de frecuencia superiores a 50 Hz (teniendo presente la ocasional deriva de la frecuencia de red).
#     Los filtros FIR se diseñan utilizando la técnica equiripple y moving average, con devío máximo admisible en banda de paso de 50mV.
#     Fuente: https://www.researchgate.net/publication/271273652_Filtrado_Basico_de_Senales_Biomedicas
# </div>

# %%
#%% Inicialización
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.signal as sig
import scipy.fftpack as sc
import scipy.io

#%% Generación de señales de prueba

# Cargo el registro electrocardiográfico (ECG)
mat = scipy.io.loadmat('ECG_TP4.mat')

ecg_lead = mat['ecg_lead']                                          # Registro de ECG muestreado a 𝑓𝑠=1  KHz durante una prueba de esfuerzo
qrs_pattern1 = mat['qrs_pattern1']                                  # Complejo de ondas QRS normal
heartbeat_pattern1 = mat['heartbeat_pattern1']                      # Latido normal
heartbeat_pattern2 = mat['heartbeat_pattern2']                      # Latido de origen ventricular
qrs_detections = mat['qrs_detections']                              # Vector con las localizaciones (en # de muestras) donde ocurren los latidos

# Frecuencia/periodo de muestreo
fs = 1000                                                           # Frecuencia de muestreo (en Hz)
ts = 1/fs                                                           # Periodo de muestreo

# %%
# Señal ECG
ecg_N = 10000                                                       # Cantidad de muestras ecg a graficar

ecg_tt = np.linspace(0, (ecg_N-1)*ts, ecg_N).flatten()              # Vector de sampleo temporal
ecg_spectrum = (2/ecg_N)*np.abs(sc.fft(ecg_lead[:ecg_N].flatten())) # Espectro de la señal ECG
ecg_half_spectrum = ecg_spectrum[:ecg_N//2]                         # Parte util del espectro de la señal ECG
ecg_ff = np.linspace(0, fs/2, ecg_N/2).flatten()                    # Vector de sampleo en frecuecia

#%% Generación de señales de prueba

# Registro ECG en tiempo
plt.figure(1)
plt.title('Registro electrocardiográfico ECG')
plt.xlabel('Tiempo [seg]')
plt.ylabel('Amplitud [mV]')
plt.grid(which='both', axis='both')
plt.plot(ecg_tt, ecg_lead[:ecg_N], color='b')
plt.show()

# Registro ECG en frecuencia
plt.figure(2)
plt.title('Espectro registro electrocardiográfico ECG')
plt.xlabel('Frecuecnia [Hz]')
plt.ylabel('Amplitud [mV]')
plt.grid(which='both', axis='both')
plt.stem(ecg_ff, ecg_half_spectrum)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   import sys

# %%
# Señal QRS
qrs_N = len(qrs_pattern1)

qrs_tt = np.linspace(0, (qrs_N-1)*ts, qrs_N).flatten()                  # Vector de sampleo temporal señal QRS
qrs_spectrum = (2/qrs_N)*np.abs(sc.fft(qrs_pattern1[:qrs_N].flatten()))
qrs_half_spectrum = qrs_spectrum[:qrs_N//2]
qrs_ff = np.linspace(0, fs/2, qrs_N/2)

# Registro QRS en tiempo
plt.figure(3)
plt.title('Complejo QRS')
plt.xlabel('Tiempo [seg]')
plt.ylabel('Amplitud [mV]')
plt.grid(which='both', axis='both')
plt.plot(qrs_tt, qrs_pattern1[:qrs_N], color='b')
plt.show()

# Registro QRS en frecuncia
plt.figure(4)
plt.title('Espectro complejo QRS')
plt.xlabel('Frecuecnia [Hz]')
plt.ylabel('Amplitud [mV]')
plt.stem(qrs_ff, qrs_half_spectrum)
plt.grid(which='both', axis='both')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   import sys

# %%
# Señal heartbeat_pattern1 y heartbeat_pattern2
hb_p1_N = len(heartbeat_pattern1)
hb_p2_N = len(heartbeat_pattern2)

hb_p1_tt = np.linspace(0, (hb_p1_N-1)*ts, hb_p1_N).flatten()
hb_p2_tt = np.linspace(0, (hb_p2_N-1)*ts, hb_p2_N).flatten()

hb_p1_spectrum = (2/hb_p1_N)*np.abs(sc.fft(heartbeat_pattern1[:hb_p1_N].flatten()))
hb_p2_spectrum = (2/hb_p2_N)*np.abs(sc.fft(heartbeat_pattern2[:hb_p2_N].flatten()))

hb_p1_half_spectrum = hb_p1_spectrum[:hb_p1_N//2]
hb_p2_half_spectrum = hb_p2_spectrum[:hb_p2_N//2]

hb_p1_ff = np.linspace(0, fs/2, hb_p1_N/2)
hb_p2_ff = np.linspace(0, fs/2, hb_p2_N/2)

# Registros heartbeat_pattern1 y heartbeat_pattern2 en tiempo
plt.figure(5)
plt.title('Patrón de latidos promedio')
plt.xlabel('Tiempo [seg]')
plt.ylabel('Amplitud [mV]')
plt.grid(which='both', axis='both')
plt.plot(hb_p1_tt, heartbeat_pattern1[:hb_p1_N], label='Latido Normal')
plt.plot(hb_p2_tt, heartbeat_pattern2[:hb_p2_N], label='Latido Ventricular')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

# Registros heartbeat_pattern1 y heartbeat_pattern2 en frecuencia
plt.figure(6)
plt.title('Espectros patrón de latidos promedio')
plt.xlabel('Frecuecnia [Hz]')
plt.ylabel('Amplitud [mV]')
plt.grid(which='both', axis='both')
plt.stem(hb_p1_ff, hb_p1_half_spectrum, linefmt='-', label='Latido Normal')
plt.stem(hb_p2_ff, hb_p2_half_spectrum, linefmt=':', label='Latido Ventricular')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   from ipykernel import kernelapp as app

# %%
# Señal qrs_detections
qrs_det_N = len(qrs_detections)

qrs_det_tt = np.linspace(0, qrs_det_N-1, qrs_det_N)

# Vector donde ocurren los latidos
plt.figure(7)
plt.title('Vector donde ocurren los latidos')
plt.xlabel('Latido [indice]')
plt.ylabel('Muestra [indice]')
plt.grid(which='both', axis='both')
plt.plot(qrs_det_tt, qrs_detections[:qrs_det_N], color='b')
plt.show()

# %% [markdown]
# c) Diseñe **al menos** dos filtros FIR y dos IIR para su comparación. Verifique que la respuesta en frecuencia responda a la plantilla de diseño

# %%
# Filtro FIR1_PA
data = np.load('FIR1_PA_EQUIRIPPLE_N_2200.npz')
h_FIR1_pa = data['ba']
b_FIR1_pa = h_FIR1_pa[0]
a_FIR1_pa = h_FIR1_pa[1]
FIR1_pa_ww, FIR1_pa_hh = sig.freqz(b_FIR1_pa, a_FIR1_pa)
FIR1_pa_ww = FIR1_pa_ww / np.pi

# Filtro FIR1_PB
data = np.load('FIR1_PB_EQUIRIPPLE_N_221.npz')
h_FIR1_pb = data['ba']
b_FIR1_pb = h_FIR1_pb[0]
a_FIR1_pb = h_FIR1_pb[1]
FIR1_pb_ww, FIR1_pb_hh = sig.freqz(b_FIR1_pb, a_FIR1_pb)
FIR1_pb_ww = FIR1_pb_ww / np.pi

# Respuesta en frecuencia filtro FIR1_pb_N_221
plt.figure(8)
plt.title('Respuesta en frecuencia FIR Equiripple PB: N = 221')
plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Amplitud [dB]')
plt.grid(which='both', axis='both')
plt.plot(FIR1_pb_ww, 20*np.log10(abs(FIR1_pb_hh)), label='Modulo', color='b')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

# Respuesta en frecuencia filtro FIR1_pa_N_2200
plt.figure(9)
plt.title('Respuesta en frecuencia FIR Equiripple PA: N = 2200')
plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Amplitud [dB]')
plt.grid(which='both', axis='both')
plt.plot(FIR1_pa_ww, 20*np.log10(abs(FIR1_pa_hh)), label='Modulo', color='b')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

# %%
# Filtro FIR2_PA
data = np.load('FIR2_PA_WINDOW_BARLETT_N_2200.npz')
h_FIR2_pa = data['ba']
b_FIR2_pa = h_FIR2_pa[0]
a_FIR2_pa = h_FIR2_pa[1]
FIR2_pa_ww, FIR2_pa_hh = sig.freqz(b_FIR2_pa, a_FIR2_pa)
FIR2_pa_ww = FIR2_pa_ww / np.pi

# Filtro FIR1_PB
data = np.load('FIR2_PB_WINDOW_BARLETT_N_222.npz')
h_FIR2_pb = data['ba']
b_FIR2_pb = h_FIR2_pb[0]
a_FIR2_pb = h_FIR2_pb[1]
FIR2_pb_ww, FIR2_pb_hh = sig.freqz(b_FIR2_pb, a_FIR2_pb)
FIR2_pb_ww = FIR2_pb_ww / np.pi

# Respuesta en frecuencia filtro FIR2_pb_N_222
plt.figure(10)
plt.title('Respuesta en frecuencia FIR PB: N = 222')
plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Amplitud [dB]')
plt.grid(which='both', axis='both')
plt.plot(FIR2_pb_ww, 20*np.log10(abs(FIR2_pb_hh)), label='Modulo', color='b')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

# Respuesta en frecuencia filtro FIR2_pa_N_2200
plt.figure(11)
plt.title('Respuesta en frecuencia FIR PA: N = 2200')
plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Amplitud [dB]')
plt.grid(which='both', axis='both')
plt.plot(FIR2_pa_ww, 20*np.log10(abs(FIR2_pa_hh)), label='Modulo', color='b')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

# %%
# Filtro IIR1_PA
data = np.load('IIR1_PA_CHEV2_N_4.npz')
h_IIR1_pa = data['ba']
b_IIR1_pa = h_IIR1_pa[0]
a_IIR1_pa = h_IIR1_pa[1]
IIR1_pa_ww, IIR1_pa_hh = sig.freqz(b_IIR1_pa, a_IIR1_pa)
IIR1_pa_ww = IIR1_pa_ww / np.pi

# Filtro IIR1_PB
data = np.load('IIR1_PB_CHEV2_N_11.npz')
h_IIR1_pb = data['ba']
b_IIR1_pb = h_IIR1_pb[0]
a_IIR1_pb = h_IIR1_pb[1]
IIR1_pb_ww, IIR1_pb_hh = sig.freqz(b_IIR1_pb, a_IIR1_pb)
IIR1_pb_ww = IIR1_pb_ww / np.pi

# Respuesta en frecuencia filtro IIR1_pb_N_11
plt.figure(12)
plt.title('Respuesta en frecuencia IIR Chevichef2 PB: N = 11')
plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Amplitud [dB]')
plt.grid(which='both', axis='both')
plt.plot(IIR1_pb_ww, 20*np.log10(abs(IIR1_pb_hh)), label='Modulo', color='b')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

# Respuesta en frecuencia filtro IIR1_pa_N_4
plt.figure(13)
plt.title('Respuesta en frecuencia IIR Chevichef2 PA: N = 4')
plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Amplitud [dB]')
plt.grid(which='both', axis='both')
plt.plot(IIR1_pa_ww, 20*np.log10(abs(IIR1_pa_hh)), label='Modulo', color='b')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

# %%
# Filtro IIR2_PA
data = np.load('IIR2_PA_CAUER_N_3.npz')
h_IIR2_pa = data['ba']
b_IIR2_pa = h_IIR2_pa[0]
a_IIR2_pa = h_IIR2_pa[1]
IIR2_pa_ww, IIR2_pa_hh = sig.freqz(b_IIR2_pa, a_IIR2_pa)
IIR2_pa_ww = IIR2_pa_ww / np.pi

# Filtro IIR2_PB
data = np.load('IIR2_PB_CAUER_N_5.npz')
h_IIR2_pb = data['ba']
b_IIR2_pb = h_IIR2_pb[0]
a_IIR2_pb = h_IIR2_pb[1]
IIR2_pb_ww, IIR2_pb_hh = sig.freqz(b_IIR2_pb, a_IIR2_pb)
IIR2_pb_ww = IIR2_pb_ww / np.pi

# Respuesta en frecuencia filtro IIR2_pb_N_5
plt.figure(14)
plt.title('Respuesta en frecuencia IIR Eliptico PB: N = 5')
plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Amplitud [dB]')
plt.grid(which='both', axis='both')
plt.plot(IIR2_pb_ww, 20*np.log10(abs(IIR2_pb_hh)), label='Modulo', color='b')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

# Respuesta en frecuencia filtro IIR2_pa_N_3
plt.figure(15)
plt.title('Respuesta en frecuencia IIR Eliptico PA: N = 3')
plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Amplitud [dB]')
plt.grid(which='both', axis='both')
plt.plot(IIR2_pa_ww, 20*np.log10(abs(IIR2_pa_hh)), label='Modulo', color='b')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

# %% [markdown]
# d) Evalúe el rendimiento de los filtros que haya diseñado:
#
#  1. Verifique que filtra las señales interferentes
#  2. Verifique que es inocuo en las zonas donde no hay interferentes

# %%
# Segmentos de interés #
########################
# Puede tomar como referencia los siguientes segmentos, aunque si lo considera, también
# puede incluir otros que considere importantes para evaluar el rendimiento.

zonas_con_interf_baja_frec = ( 
        np.array([12, 12.4]) *60*fs, # minutos a muestras
        np.array([15, 15.2]) *60*fs, # minutos a muestras
        )


zonas_sin_interf = ( 
        np.array([5, 5.2]) *60*fs, # minutos a muestras
        [4000, 5500], # muestras
        [10e3, 11e3], # muestras
        )

##########################################
# Acá podés generar los gráficos pedidos #
##########################################

def plot_filtered_signals(b_pb, a_pb, b_pa, a_pa, i, ecg_N_start, ecg_N_end):
    N = len(ecg_lead[ecg_N_start:ecg_N_end])
    tt = np.linspace(0, (N-1)*ts, N).flatten()

    ecg_filter_pa = sig.lfilter(b_pa, a_pa, ecg_lead.flatten())
    ecg_filter_full = sig.lfilter(b_pb, a_pb, ecg_filter_pa.flatten())
    
    ecg_ff = np.linspace(0.0, fs/2, N/2).flatten()
    
    plt.figure(i + 1)
    plt.plot(tt, ecg_lead[ecg_N_start:ecg_N_end], label='Original')
    plt.plot(tt, ecg_filter_pa[ecg_N_start:ecg_N_end], label= 'Filtrado_PA')
    plt.plot(tt, ecg_filter_full[ecg_N_start:ecg_N_end], label= 'Filtrado_PA_PB')
    plt.title('Registro ECG')
    plt.xlabel('Tiempo [seg]')
    plt.ylabel('Amplitud [mV]')
    plt.grid(which='both', axis='both')
    axes_hdl = plt.gca()
    axes_hdl.legend()
    plt.show()
    
    ecg_spectrum = (2/N)*np.abs(sc.fft(ecg_lead[ecg_N_start:ecg_N_end].flatten()))
    ecg_half_spectrum = ecg_spectrum[:N//2] 

    ecg_filter_pa_spectrum = (2/N)*np.abs(sc.fft(ecg_filter_pa[ecg_N_start:ecg_N_end].flatten()))
    ecg_filter_pa_half_spectrum = ecg_filter_pa_spectrum[:N//2] 

    ecg_filter_full_spectrum = (2/N)*np.abs(sc.fft(ecg_filter_full[ecg_N_start:ecg_N_end].flatten()))
    ecg_filter_full_half_spectrum = ecg_filter_full_spectrum[:N//2] 

    plt.figure(i + 4)

    plt.plot(ecg_ff, ecg_half_spectrum, label='Original', color='b')
    plt.plot(ecg_ff, ecg_filter_pa_half_spectrum, label='Filtrado_PA', color='g')
    plt.plot(ecg_ff, ecg_filter_full_half_spectrum, label='Filtrado_PA_PB', color='r')

    plt.title('Espectro registro ECG')
    plt.xlabel('Frecuencia [Hz]')
    plt.ylabel('Amplitud [mV]')
    plt.grid(which='both', axis='both')
    axes_hdl = plt.gca()
    axes_hdl.legend()
    plt.show()
    
    return None

# %%
# FIR1_Equiripple

# Filtro pasabajos

# Fsb = 50 Hz
# Fpb = 45 Hz
# Asb = 50 mV
# Apb = 50 mV
# Order = 221

# Filtro pasaaltos

# Fsb = 0.5 Hz
# Fpb = 1 Hz
# Asb = 50 mV
# Apb = 50 mV
# Order = 2200

# Filtro FIR1_PA
data = np.load('FIR1_PA_EQUIRIPPLE_N_2200.npz')
h_FIR1_pa = data['ba']
b_FIR1_pa = h_FIR1_pa[0]
a_FIR1_pa = h_FIR1_pa[1]
FIR1_pa_ww, FIR1_pa_hh = sig.freqz(b_FIR1_pa, a_FIR1_pa)
FIR1_pa_ww = FIR1_pa_ww / np.pi

# Filtro FIR1_PB
data = np.load('FIR1_PB_EQUIRIPPLE_N_221.npz')
h_FIR1_pb = data['ba']
b_FIR1_pb = h_FIR1_pb[0]
a_FIR1_pb = h_FIR1_pb[1]
FIR1_pb_ww, FIR1_pb_hh = sig.freqz(b_FIR1_pb, a_FIR1_pb)
FIR1_pb_ww = FIR1_pb_ww / np.pi

plt.close('all')

for i in range(3):
    ecg_N_start = int(zonas_sin_interf[i][0])
    ecg_N_end = int(zonas_sin_interf[i][1])
       
    plot_filtered_signals(b_FIR1_pb, a_FIR1_pb, b_FIR1_pa, a_FIR1_pa, i, ecg_N_start, ecg_N_end)

# Filtrado zonas con interferencia
for i in range(2):
    ecg_N_start = int(zonas_con_interf_baja_frec[i][0])
    ecg_N_end = int(zonas_con_interf_baja_frec[i][1])
    
    plot_filtered_signals(b_FIR1_pb, a_FIR1_pb, b_FIR1_pa, a_FIR1_pa, i + 7, ecg_N_start, ecg_N_end)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
# FIR2_Window_Barlett

# Filtro pasabajos

# Fsb = 50 Hz
# Fpb = 45 Hz
# Asb = 50 mV
# Apb = 50 mV
# Order = 222

# Filtro pasaaltos

# Fsb = 0.5 Hz
# Fpb = 1 Hz
# Asb = 50 mV
# Apb = 50 mV
# Order = 2200

# Filtro FIR2_PA
data = np.load('FIR2_PA_WINDOW_BARLETT_N_2200.npz')
h_FIR2_pa = data['ba']
b_FIR2_pa = h_FIR2_pa[0]
a_FIR2_pa = h_FIR2_pa[1]
FIR2_pa_ww, FIR2_pa_hh = sig.freqz(b_FIR2_pa, a_FIR2_pa)
FIR2_pa_ww = FIR2_pa_ww / np.pi

# Filtro FIR2_PB
data = np.load('FIR2_PB_WINDOW_BARLETT_N_222.npz')
h_FIR2_pb = data['ba']
b_FIR2_pb = h_FIR2_pb[0]
a_FIR2_pb = h_FIR2_pb[1]
FIR2_pb_ww, FIR2_pb_hh = sig.freqz(b_FIR2_pb, a_FIR2_pb)
FIR2_pb_ww = FIR2_pb_ww / np.pi

plt.close('all')

for i in range(3):
    ecg_N_start = int(zonas_sin_interf[i][0])
    ecg_N_end = int(zonas_sin_interf[i][1])
       
    plot_filtered_signals(b_FIR2_pb, a_FIR2_pb, b_FIR2_pa, a_FIR2_pa, i, ecg_N_start, ecg_N_end)

# Filtrado zonas con interferencia
for i in range(2):
    ecg_N_start = int(zonas_con_interf_baja_frec[i][0])
    ecg_N_end = int(zonas_con_interf_baja_frec[i][1])
    
    plot_filtered_signals(b_FIR2_pb, a_FIR2_pb, b_FIR2_pa, a_FIR2_pa, i + 7, ecg_N_start, ecg_N_end)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
# IIR1_Chevichef2

# Filtro pasabajos

# Fsb = 50 Hz
# Fpb = 45 Hz
# Asb = 50 mV
# Apb = 50 mV
# Order = 11

# Filtro pasaaltos

# Fsb = 0.5 Hz
# Fpb = 1 Hz
# Asb = 50 mV
# Apb = 50 mV
# Order = 4

# Filtro IIR1_PA
data = np.load('IIR1_PA_CHEV2_N_4.npz')
h_IIR1_pa = data['ba']
b_IIR1_pa = h_IIR1_pa[0]
a_IIR1_pa = h_IIR1_pa[1]
IIR1_pa_ww, IIR1_pa_hh = sig.freqz(b_IIR1_pa, a_IIR1_pa)
IIR1_pa_ww = IIR1_pa_ww / np.pi

# Filtro IIR1_PB
data = np.load('IIR1_PB_CHEV2_N_11.npz')
h_IIR1_pb = data['ba']
b_IIR1_pb = h_IIR1_pb[0]
a_IIR1_pb = h_IIR1_pb[1]
IIR1_pb_ww, IIR1_pb_hh = sig.freqz(b_IIR1_pb, a_IIR1_pb)
IIR1_pb_ww = IIR1_pb_ww / np.pi

plt.close('all')

for i in range(3):
    ecg_N_start = int(zonas_sin_interf[i][0])
    ecg_N_end = int(zonas_sin_interf[i][1])
       
    plot_filtered_signals(b_IIR1_pb, a_IIR1_pb, b_IIR1_pa, a_IIR1_pa, i, ecg_N_start, ecg_N_end)

# Filtrado zonas con interferencia
for i in range(2):
    ecg_N_start = int(zonas_con_interf_baja_frec[i][0])
    ecg_N_end = int(zonas_con_interf_baja_frec[i][1])
    
    plot_filtered_signals(b_IIR1_pb, a_IIR1_pb, b_IIR1_pa, a_IIR1_pa, i + 7, ecg_N_start, ecg_N_end)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
# IIR2_Eliptico (Cauer)

# Filtro pasabajos

# Fsb = 50 Hz
# Fpb = 45 Hz
# Asb = 50 mV
# Apb = 50 mV
# Order = 5

# Filtro pasaaltos

# Fsb = 0.5 Hz
# Fpb = 1 Hz
# Asb = 50 mV
# Apb = 50 mV
# Order = 3

# Filtro IIR2_PA
data = np.load('IIR2_PA_CAUER_N_3.npz')
h_IIR2_pa = data['ba']
b_IIR2_pa = h_IIR2_pa[0]
a_IIR2_pa = h_IIR2_pa[1]
IIR2_pa_ww, IIR2_pa_hh = sig.freqz(b_IIR2_pa, a_IIR2_pa)
IIR2_pa_ww = IIR2_pa_ww / np.pi

# Filtro IIR2_PB
data = np.load('IIR2_PB_CAUER_N_5.npz')
h_IIR2_pb = data['ba']
b_IIR2_pb = h_IIR2_pb[0]
a_IIR2_pb = h_IIR2_pb[1]
IIR2_pb_ww, IIR2_pb_hh = sig.freqz(b_IIR2_pb, a_IIR2_pb)
IIR2_pb_ww = IIR2_pb_ww / np.pi

plt.close('all')

for i in range(3):
    ecg_N_start = int(zonas_sin_interf[i][0])
    ecg_N_end = int(zonas_sin_interf[i][1])
       
    plot_filtered_signals(b_IIR2_pb, a_IIR2_pb, b_IIR2_pa, a_IIR2_pa, i, ecg_N_start, ecg_N_end)

# Filtrado zonas con interferencia
for i in range(2):
    ecg_N_start = int(zonas_con_interf_baja_frec[i][0])
    ecg_N_end = int(zonas_con_interf_baja_frec[i][1])
    
    plot_filtered_signals(b_IIR2_pb, a_IIR2_pb, b_IIR2_pa, a_IIR2_pa, i + 7, ecg_N_start, ecg_N_end)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Se observa como los fltros pasaaltos filtran las componentes de frecuencia contínua y las bajas frecuencias del registro ECG.
#     Además, se observa mayor distosión en las señales al aplicar filtros IIR comparado con los FIR, lo que se debe a que los primeros no permiten lograr fase lineal, mientras que los segundos si.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5)</b> Utilice las siguientes metodologías <b>no lineales</b> de estimación-substracción para la remoción de la interferencia de línea de base, y compare con las técnicas lineales del punto anterior en las mismas regiones. Luego discuta las ventajas y desventajas de cada técnica.
# </div>

# %% [markdown]
# a) Estimación del movimiento de línea de base a partir del filtrado de mediana. A partir de la siguiente estimación del movimiento de línea de base
#
# $$ \hat{b} = \mathop{med}_{600} \{ \mathop{med}_{200} \{s\} \} $$
#
# Donde $s$ representa la señal de ECG a partir de la que estimamos el movimiento de la línea de base $ \hat{b}$. El operador $\mathop{med}_{200}$ calcula muestra a muestra la mediana en los 200 ms previos a la muestra actual. Luego dicha estimación la substraemos para estimar la actividad eléctrica cardíaca $\hat{x}$
#
# $$ \hat{x} = s - \hat{b} $$

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Puede utilizar la implementación del <a href="https://docs.scipy.org/doc/scipy/reference/tutorial/signal.html#median-filter">filtro de mediana provista en <b>scipy.signal</b></a>
# </div>

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# b) Estimación del movimiento de línea de base a partir de los segmentos isoeléctricos de cada latido. A partir de las detecciones provistas, puede estimar aproximadamente el nivel isoeléctrico, es decir el momento donde la actividad eléctrica cardíaca es **nula**. El intervalo entre la onda P y Q, es un buen momento para estimar las características de las señales interferentes que originan el movimiento de la línea de base.
#
# <img src="./pq.png" align="center" width="80%" />
#
# Para la localización del segmento PQ puede valerse de la localización de cada latido (líneas rojas verticales) y a partir de la misma, anticipar un tiempo adecuado de manera tal de no incluir la onda P ni Q. Puede ayudarse con el latido promedio de un latido normal para establecer dicho intervalo.
#
# Recuerde que la señal de línea de base debe estar muestreada a la misma frecuencia que el ECG, por lo que debería remuestrear dicha señal (puede usar la función de interpolación spline para ello).

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Puede utilizar la función de interpolación <a href="https://docs.scipy.org/doc/scipy-0.18.1/reference/generated/scipy.interpolate.CubicSpline.html">spline <b>scipy.interpolate.CubicSpline</b></a>
# </div>

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>6)</b> Para la señal de ECG provista junto con este documento, aplique el concepto de <b>filtro adaptado</b> y otras técnicas de filtrado digital para diseñar un detector de latidos. Los patrones provistos son:
#
# </div>

# %% [markdown]
#  - **qrs_pattern1**: Complejo de ondas QRS normal
#  - **heartbeat_pattern1**: Latido normal
#  - **heartbeat_pattern2**: Latido de origen ventricular

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Revise el concepto de filtro adaptado en <a href="http://en.wikipedia.org/wiki/Matched_filter">Wikipedia</a>, o la bibliografía de la materia (Porat 14.4.9).
# </div>

# %%
import scipy.io as sio

##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# para listar las variables que hay en el archivo
#io.whosmat('ECG_TP4.mat')
mat_struct = sio.loadmat('./ECG_TP4.mat')

ecg_one_lead = vertical_flaten(mat_struct['ecg_lead'])
N = len(ecg_one_lead)

hb_1 = vertical_flaten(mat_struct['heartbeat_pattern1'])

plt.figure(1)
plt.plot(ecg_one_lead[5000:12000])

plt.figure(2)
plt.plot(hb_1)

# %% [markdown]
# a) Explique conceptualmente cómo podría realizar un detector de latidos con la señal resultante del filtro adaptado. Discuta la utilidad y limitaciones de este método.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
#
#    b) Realice la detección de los latidos, comparando las detecciones obtenidas con las que se incluyen en la variable **qrs_detections**. Proponga alguna métrica para cuantificar las diferencias.

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################
